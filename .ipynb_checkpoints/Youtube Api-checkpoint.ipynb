# %% [markdown]
# ## Installing and Importing Libraries

# %%
# !pip install --upgrade google-api-python-client
# !pip install nltk
! pip install isodate
# Out:
# Requirement already satisfied: google-api-python-client in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (2.100.0)
# Requirement already satisfied: httplib2<1.dev0,>=0.15.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0.dev0,>=1.19.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-python-client) (2.23.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-python-client) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.60.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.24.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (4.9)
# Requirement already satisfied: urllib3<2.0 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from httplib2<1.dev0,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0.dev0,>=1.19.0->google-api-python-client) (0.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.7.22)
# Requirement already satisfied: nltk in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (3.8.1)
# Requirement already satisfied: click in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: isodate in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (0.6.1)
# Requirement already satisfied: six in /home/sikander/miniconda3/envs/myenv1/lib/python3.9/site-packages (from isodate) (1.16.0)

# %%
#for acessing google api
from googleapiclient.discovery import build
from dateutil import parser
from IPython.display import JSON

# %% [markdown]
# ## Data visualization Packages

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import pandas as pd

# %% [markdown]
# ## Natural Language Processing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download("stopwords")
nltk.download("punkt")
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sikander/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/sikander/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Importing key
#
#
# 1. Link to create YouTube API Key: https://console.cloud.google.com/
# 2.  Link to Google YouTube Data API documentation: https://developers.google.com/youtube/v3

# %%
api_key = 'AIzaSyCukGXQqAXPpVMJRxXRIqRIBKXA9ycylLk'

# %% [markdown]
# ## Channel IDs

# %%
channel_ids=['UCCWi3hpnq_Pe03nGxuS7isg','UCoOae5nYA7VqaXzerajD0lg']
##ad more channels if you like

# %% [markdown]
# ## Connecting with api

# %%
api_service_name='youtube'
api_version='v3'
youtube=build(
    api_service_name,api_version,developerKey=api_key
)

# %% [markdown]
# ## Defining functions for accessing the Data

# %%
def get_channel_stats(youtube,channel_ids):
    '''
    Get Channel stats
    
    Params:
    ------
    youtube:build object of Youtube api
    channel_ids:list of channel IDS

    Returns:
    ------
    dateframe with all channel stats for each channel ID

    '''

    all_data=[]
    request=youtube.channels().list(
        part='snippet,contentDetails,statistics',
        id=','.join(channel_ids)
        
    )
    response=request.execute()
    ## looping through items
    for item in response['items']:
        data={'channelName':item['snippet']['title'],
              'subscribers':item['statistics']['subscriberCount'],
              'views':item['statistics']['viewCount'],
              'totalVideos':item['statistics']['videoCount'],
              'playlistId':item['contentDetails']['relatedPlaylists']['uploads']
            
        }
        all_data.append(data)

    return pd.DataFrame(all_data)

# %%
def get_videos_ids(youtube,playlist_id):
    video_ids=[]

    request=youtube.playlistItems().list(
        part='snippet,contentDetails',
        playlistId=playlist_id,
        maxResults=50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
    
def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)

# %% [markdown]
# ## Channel stats

# %%
channel_stats=get_channel_stats(youtube,channel_ids)

# %%
channel_stats
# Out:
#   channelName subscribers      views totalVideos                playlistId
# 0  Ali Abdaal     4740000  358912284         706  UUoOae5nYA7VqaXzerajD0lg
# 1     CampusX      121000   11998840        1137  UUCWi3hpnq_Pe03nGxuS7isg

# %% [markdown]
# ## Playlist ID

# %%
playlist_id='UUoOae5nYA7VqaXzerajD0lg'

# %%
video_ids=get_videos_ids(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 703

# %%
video_df=get_video_details(youtube,video_ids=video_ids)
video_df
# Out:
#         video_id channelTitle  \
# 0    hBEKGBLAB80   Ali Abdaal
# 1    V9SmqAoawH8   Ali Abdaal
# 2    iBM0PToZ2VM   Ali Abdaal
# 3    SjcvBFfMulY   Ali Abdaal
# 4    Pr0mI_gkS4k   Ali Abdaal
# ..           ...          ...
# 698  7APfFjfnNBc   Ali Abdaal
# 699  gBpBLTSCb4s   Ali Abdaal
# 700  Va0tSdPADpA   Ali Abdaal
# 701  XJHM0fEH3ss   Ali Abdaal
# 702  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0                8 Simple Hacks to Improve Your Health
# 1                     Why you should work for free 🧑‍💻
# 2                        The Problem with Discipline 😓
# 3            My Most Productive Desk Setup Ever (2023)
# 4                     You Are Not The Main Character ❌
# ..                                                 ...
# 698  Payphone (Maroon 5) - Katherine Macfarland & A...
# 699            6med UKCAT Crash Course - In a Nutshell
# 700             6med BMAT Crash Course - In a Nutshell
# 701  Rolling in the Deep (Adele) - Duranka Perera &...
# 702           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    Get 60 days of Headspace for free: https://hea...
# 1    📚 If you liked this, you might like my new boo...
# 2    📚 If you liked this, you might like my new boo...
# 3    If you want to use the tips from this video in...
# 4    📚 If you liked this, you might like my new boo...
# ..                                                 ...
# 698  First cover of 2017! We both love this song, s...
# 699  The 6med UKCAT Crash Course is the most effect...
# 700  The 6med BMAT Crash Course is the most effecti...
# 701  Our first 'proper' video! One of our all-time ...
# 702  First attempt at playing around with this sort...
#
#                                                   tags           publishedAt  \
# 0                              [Ali Abdaal, Ali abdal]  2023-09-22T13:30:28Z
# 1                              [Ali Abdaal, Ali abdal]  2023-09-22T12:00:26Z
# 2                              [Ali Abdaal, Ali abdal]  2023-09-20T12:00:39Z
# 3    [Ali Abdaal, Ali abdal, ali abdaal books, best...  2023-09-19T13:00:32Z
# 4                              [Ali Abdaal, Ali abdal]  2023-09-19T12:00:28Z
# ..                                                 ...                   ...
# 698        [payphone, maroon 5, acoustic cover, cover]  2017-01-04T23:13:51Z
# 699            ed, medical school, ukcat, medicine]  2016-05-09T18:45:18Z
# 700           [BMAT, 6med, medicine, medical students]  2016-04-27T09:04:49Z
# 701      [rolling in the deep, adele, cover, acoustic]  2016-04-05T09:05:29Z
# 702                                               None  2016-03-27T19:30:11Z
#
#     viewCount likeCount favouriteCount commentCount  duration definition  \
# 0      106867      5121           None          282  PT13M22S         hd
# 1       18379      1502           None            6     PT44S         hd
# 2       44555      4141           None           97     PT47S         hd
# 3      151093      5083           None          248  PT16M39S         hd
# 4       22308      1684           None           23     PT32S         hd
# ..        ...       ...            ...          ...       ...        ...
# 698     86577      2157           None          123   PT2M35S         hd
# 699     15647       112           None            5   PT2M11S         hd
# 700     38641       284           None            9   PT2M18S         hd
# 701     57308       720           None           33   PT2M29S         hd
# 702    119189      1482           None          139   PT1M43S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 698   false
# 699   false
# 700   false
# 701   false
# 702   false
#
# [703 rows x 13 columns]

# %% [markdown]
# ## Checking for NULL Values

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount      False
# duration          False
# definition        False
# caption           False
# dtype: bool

# %% [markdown]
# ## Checking Data Types

# %%
video_df.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %% [markdown]
# ## Converting Datatypes to numerical in order to plot them later

# %%
# Convert count columns to numeric
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
# convert duration to seconds
import isodate
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df[['durationSecs','duration']]
# Out:
#        durationSecs  duration
# 0   0 days 00:13:22  PT13M22S
# 1   0 days 00:00:44     PT44S
# 2   0 days 00:00:47     PT47S
# 3   0 days 00:16:39  PT16M39S
# 4   0 days 00:00:32     PT32S
# ..              ...       ...
# 698 0 days 00:02:35   PT2M35S
# 699 0 days 00:02:11   PT2M11S
# 700 0 days 00:02:18   PT2M18S
# 701 0 days 00:02:29   PT2M29S
# 702 0 days 00:01:43   PT1M43S
#
# [703 rows x 2 columns]

# %% [markdown]
# ## Adding tag count

# %%
# Add tag count
video_df['tagCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df
# Out:
#         video_id channelTitle  \
# 0    hBEKGBLAB80   Ali Abdaal
# 1    V9SmqAoawH8   Ali Abdaal
# 2    iBM0PToZ2VM   Ali Abdaal
# 3    SjcvBFfMulY   Ali Abdaal
# 4    Pr0mI_gkS4k   Ali Abdaal
# ..           ...          ...
# 698  7APfFjfnNBc   Ali Abdaal
# 699  gBpBLTSCb4s   Ali Abdaal
# 700  Va0tSdPADpA   Ali Abdaal
# 701  XJHM0fEH3ss   Ali Abdaal
# 702  LQ3Mu8A7gjY   Ali Abdaal
#
#                                                  title  \
# 0                8 Simple Hacks to Improve Your Health
# 1                     Why you should work for free 🧑‍💻
# 2                        The Problem with Discipline 😓
# 3            My Most Productive Desk Setup Ever (2023)
# 4                     You Are Not The Main Character ❌
# ..                                                 ...
# 698  Payphone (Maroon 5) - Katherine Macfarland & A...
# 699            6med UKCAT Crash Course - In a Nutshell
# 700             6med BMAT Crash Course - In a Nutshell
# 701  Rolling in the Deep (Adele) - Duranka Perera &...
# 702           All of Me (John Legend) - Duranka Perera
#
#                                            description  \
# 0    Get 60 days of Headspace for free: https://hea...
# 1    📚 If you liked this, you might like my new boo...
# 2    📚 If you liked this, you might like my new boo...
# 3    If you want to use the tips from this video in...
# 4    📚 If you liked this, you might like my new boo...
# ..                                                 ...
# 698  First cover of 2017! We both love this song, s...
# 699  The 6med UKCAT Crash Course is the most effect...
# 700  The 6med BMAT Crash Course is the most effecti...
# 701  Our first 'proper' video! One of our all-time ...
# 702  First attempt at playing around with this sort...
#
#                                                   tags           publishedAt  \
# 0                              [Ali Abdaal, Ali abdal]  2023-09-22T13:30:28Z
# 1                              [Ali Abdaal, Ali abdal]  2023-09-22T12:00:26Z
# 2                              [Ali Abdaal, Ali abdal]  2023-09-20T12:00:39Z
# 3    [Ali Abdaal, Ali abdal, ali abdaal books, best...  2023-09-19T13:00:32Z
# 4                              [Ali Abdaal, Ali abdal]  2023-09-19T12:00:28Z
# ..                                                 ...                   ...
# 698        [payphone, maroon 5, acoustic cover, cover]  2017-01-04T23:13:51Z
# 699            ed, medical school, ukcat, medicine]  2016-05-09T18:45:18Z
# 700           [BMAT, 6med, medicine, medical students]  2016-04-27T09:04:49Z
# 701      [rolling in the deep, adele, cover, acoustic]  2016-04-05T09:05:29Z
# 702                                               None  2016-03-27T19:30:11Z
#
#      viewCount  likeCount  favouriteCount  commentCount  duration definition  \
# 0     106867.0     5121.0             NaN         282.0  PT13M22S         hd
# 1      18379.0     1502.0             NaN           6.0     PT44S         hd
# 2      44555.0     4141.0             NaN          97.0     PT47S         hd
# 3     151093.0     5083.0             NaN         248.0  PT16M39S         hd
# 4      22308.0     1684.0             NaN          23.0     PT32S         hd
# ..         ...        ...             ...           ...       ...        ...
# 698    86577.0     2157.0             NaN         123.0   PT2M35S         hd
# 699    15647.0      112.0             NaN           5.0   PT2M11S         hd
# 700    38641.0      284.0             NaN           9.0   PT2M18S         hd
# 701    57308.0      720.0             NaN          33.0   PT2M29S         hd
# 702   119189.0     1482.0             NaN         139.0   PT1M43S         hd
#
#     caption    durationSecs  tagCount
# 0     false 0 days 00:13:22         2
# 1     false 0 days 00:00:44         2
# 2     false 0 days 00:00:47         2
# 3     false 0 days 00:16:39        19
# 4     false 0 days 00:00:32         2
# ..      ...             ...       ...
# 698   false 0 days 00:02:35         4
# 699   false 0 days 00:02:11         4
# 700   false 0 days 00:02:18         4
# 701   false 0 days 00:02:29         4
# 702   false 0 days 00:01:43         0
#
# [703 rows x 15 columns]

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Finding Best performing Videos

# %%
ax = sns.barplot(x = 'title', y = 'viewCount', data = video_df.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# ## View Distribution per video

# %%
plt.figure(figsize=(12, 6))  # Adjust the figure size as needed
sns.violinplot(x=video_df['channelTitle'], y=video_df['viewCount'])
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('Channel Title')
plt.ylabel('View Count')
plt.title('Distribution of View Count by Channel Title')
plt.show()

# %% [markdown]
# ## Views vs. likes and comments

# %%
fig, ax = plt.subplots(1,2,figsize=(12,5))
sns.scatterplot(data = video_df, x = 'commentCount', y = 'viewCount', ax = ax[0])
sns.scatterplot(data = video_df, x = 'likeCount', y = 'viewCount', ax = ax[1])
# Out:
# <Axes: xlabel='likeCount', ylabel='viewCount'>

# %% [markdown]
# ## Video Duration

# %%
sns.histplot(data=video_df,x='durationSecs',bins=30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %%
## Wordcloud for video Titles

# %%
stop_words=set(stopwords.words('english'))
video_df['title_no_stopwords']=video_df['title'].apply(lambda x:[item for item in str(x).split()if item not in stop_words])
all_words=list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str=' '.join(all_words)

# %% [markdown]
# ## Defining wordcloud function

# %%
def cloud_plot(wordcloud):
    plt.figure(figsize=(30,20))
    plt.imshow(wordcloud)
    plt.axis('off')

# %%
wordcloud=WordCloud(width=2000,height=1000,random_state=1,background_color='black',colormap='viridis',collocations=False).generate(all_words_str)
cloud_plot(wordcloud)
